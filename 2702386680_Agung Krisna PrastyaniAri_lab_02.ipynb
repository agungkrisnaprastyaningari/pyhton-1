# %%
import time
print(time.ctime())
# Out:
# Tue Feb  6 06:46:56 2024

# %%
x = np.array({1, 4, 3})
x
# Out:
# array({1, 3, 4}, dtype=object)

# %%
def my_adder(a,b, c):
  """
  function to sum the number 3s
  input 3 number a, b, c
  Output the sum of a, b and c
  """

  #this is summation
  out = a + b + c
  return out

# %%
my_adder(1,2,3)
# Out:
# 6

# %%
help(my_adder)
# Out:
# Help on function my_adder in module __main__:
#
# my_adder(a, b, c)
#     function to sum the number 3s
#     input 3 number a, b, c
#     Output the sum of a, b and c

# %%
def my_thermo_stat(temp, desired_temp):
  if temp < desired_temp - 5:
      status = 'heat'
  elif temp > desired_temp + 5:
      status = 'ac'
  else:
      status = 'off'
  return status
